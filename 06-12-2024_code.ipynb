# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

# List of companies
companies = ["APPLE_data", "GOOGLE_data", "MICROSOFT_data", "AMAZON_data", "TESLA_data"]

# Feature engineering
def feature_engineering(df):
    df['Volatility'] = (df['High'] - df['Low']) / df['Low']  # Daily price range
    df.fillna(method='bfill', inplace=True)  # Fill NaN values
    return df

# Prepare data
def prepare_data(data, sequence_length):
    scaler = MinMaxScaler(feature_range=(0, 1))
    features = ['Open', 'High', 'Low', 'Volume', 'Volatility']
    data[features] = scaler.fit_transform(data[features])
    data['Adj Close'] = scaler.fit_transform(data[['Adj Close']])
    
    X, y = [], []
    for i in range(sequence_length, len(data)):
        X.append(data[features].iloc[i-sequence_length:i].values)
        y.append(data['Adj Close'].iloc[i])
    
    X, y = np.array(X), np.array(y)
    return X, y, scaler

# Sequential data split
def split_data_sequential(X, y, train_ratio=0.8):
    split_idx = int(len(X) * train_ratio)
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]
    return X_train, X_test, y_train, y_test

# Build LSTM model
def build_lstm(sequence_length, feature_size):
    model = Sequential()
    model.add(LSTM(64, return_sequences=True, input_shape=(sequence_length, feature_size)))
    model.add(LSTM(64, return_sequences=False))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1, activation='linear'))  # Output layer
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# Train LSTM
def train_lstm(X_train, y_train, X_test, y_test, sequence_length, batch_size=16, epochs=25):
    feature_size = X_train.shape[2]
    model = build_lstm(sequence_length, feature_size)
    model.fit(X_train, y_train, validation_split=0.2, epochs=epochs, batch_size=batch_size, verbose=1)
    
    # Predict and rescale
    y_pred = model.predict(X_test)
    return y_pred.flatten(), y_test

# Train and evaluate SVM and Random Forest
def train_svm_rf(X, y):
    X = X.reshape(X.shape[0], -1)  # Flatten for non-sequential models
    train_size = int(len(X) * 0.8)
    X_train, X_test = X[:train_size], X[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]
    
    # Train SVM
    svm_model = SVR(kernel='rbf')
    svm_model.fit(X_train, y_train)
    svm_pred = svm_model.predict(X_test)
    
    # Train Random Forest
    rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
    rf_model.fit(X_train, y_train)
    rf_pred = rf_model.predict(X_test)
    
    return y_test, svm_pred, rf_pred

# Main Execution
sequence_length = 50
results = {"Company": [], "Model": [], "RMSE": [], "MAE": [], "R-Squared": []}

for company in companies:
    file_path = company + ".csv"
    df = pd.read_csv(file_path, parse_dates=['Date'])
    df.set_index('Date', inplace=True)
    df = feature_engineering(df)

    # Prepare data
    X, y, scaler = prepare_data(df, sequence_length)

    # Sequential data split
    X_train, X_test, y_train, y_test = split_data_sequential(X, y)

    # Train LSTM
    lstm_pred, lstm_actual = train_lstm(X_train, y_train, X_test, y_test, sequence_length)

    # Evaluate LSTM model
    lstm_rmse = np.sqrt(mean_squared_error(lstm_actual, lstm_pred))
    lstm_mae = mean_absolute_error(lstm_actual, lstm_pred)
    lstm_r2 = r2_score(lstm_actual, lstm_pred)

    # Add LSTM results
    results["Company"].append(company)
    results["Model"].append("LSTM")
    results["RMSE"].append(lstm_rmse)
    results["MAE"].append(lstm_mae)
    results["R-Squared"].append(lstm_r2)

    # Train and evaluate SVM and Random Forest
    y_test_flat, svm_pred, rf_pred = train_svm_rf(X, y)

    # Evaluate SVM model
    svm_rmse = np.sqrt(mean_squared_error(y_test_flat, svm_pred))
    svm_mae = mean_absolute_error(y_test_flat, svm_pred)
    svm_r2 = r2_score(y_test_flat, svm_pred)
    results["Company"].append(company)
    results["Model"].append("SVM")
    results["RMSE"].append(svm_rmse)
    results["MAE"].append(svm_mae)
    results["R-Squared"].append(svm_r2)

    # Evaluate Random Forest model
    rf_rmse = np.sqrt(mean_squared_error(y_test_flat, rf_pred))
    rf_mae = mean_absolute_error(y_test_flat, rf_pred)
    rf_r2 = r2_score(y_test_flat, rf_pred)
    results["Company"].append(company)
    results["Model"].append("Random Forest")
    results["RMSE"].append(rf_rmse)
    results["MAE"].append(rf_mae)
    results["R-Squared"].append(rf_r2)

    # Plot predictions for LSTM
    plt.figure(figsize=(10, 6))
    plt.plot(lstm_actual, label='Actual')
    plt.plot(lstm_pred, label='Predicted')
    plt.title(f"{company} LSTM Prediction vs Actual")
    plt.legend()
    plt.show()

# Convert results to DataFrame
results_df = pd.DataFrame(results)

# Print results
print("\nStock Prediction Evaluation Metrics:")
print(results_df)
# Out:
# Epoch 1/25
# /var/folders/v7/c7_xhzbn47n7kzmqg4jkhntc0000gn/T/ipykernel_35081/4176298021.py:18: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill', inplace=True)  # Fill NaN values
# /Users/sindhukavyaalahari/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0264 - val_loss: 0.0025
# Epoch 2/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 3/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0020 - val_loss: 0.0024
# Epoch 4/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 5/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0016 - val_loss: 0.0029
# Epoch 6/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 7/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 8/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - val_loss: 0.0023
# Epoch 9/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 10/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0013 - val_loss: 0.0034
# Epoch 11/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 12/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 13/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 14/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.6258e-04 - val_loss: 8.8806e-04
# Epoch 15/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 16/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 17/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.9249e-04 - val_loss: 8.1805e-04
# Epoch 18/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.7035e-04 - val_loss: 8.0395e-04
# Epoch 19/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.6180e-04 - val_loss: 7.6495e-04
# Epoch 20/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.1936e-04 - val_loss: 7.3773e-04
# Epoch 21/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.5469e-04 - val_loss: 7.4296e-04
# Epoch 22/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.4158e-04 - val_loss: 8.1994e-04
# Epoch 23/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0010 - val_loss: 8.1928e-04
# Epoch 24/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.9905e-04 - val_loss: 7.2826e-04
# Epoch 25/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.1307e-04 - val_loss: 0.0010
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Epoch 1/25
# /var/folders/v7/c7_xhzbn47n7kzmqg4jkhntc0000gn/T/ipykernel_35081/4176298021.py:18: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill', inplace=True)  # Fill NaN values
# /Users/sindhukavyaalahari/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0404 - val_loss: 0.0018
# Epoch 2/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 3/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 4/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0020 - val_loss: 0.0040
# Epoch 5/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 6/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 7/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 8/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 9/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 10/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0015 - val_loss: 0.0020
# Epoch 11/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 12/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 13/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 14/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 15/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 16/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 17/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 18/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 19/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 20/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 9.3420e-04 - val_loss: 9.9574e-04
# Epoch 21/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 22/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.4928e-04 - val_loss: 0.0014
# Epoch 23/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 24/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.1250e-04 - val_loss: 0.0011
# Epoch 25/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0011 - val_loss: 9.4908e-04
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 1/25
# /var/folders/v7/c7_xhzbn47n7kzmqg4jkhntc0000gn/T/ipykernel_35081/4176298021.py:18: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill', inplace=True)  # Fill NaN values
# /Users/sindhukavyaalahari/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0154 - val_loss: 0.0016
# Epoch 2/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 3/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 4/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 5/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 6/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 7/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0012 - val_loss: 9.6680e-04
# Epoch 8/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0011 - val_loss: 0.0025
# Epoch 9/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0011 - val_loss: 8.1704e-04
# Epoch 10/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0013 - val_loss: 0.0025
# Epoch 11/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.6155e-04 - val_loss: 7.0480e-04
# Epoch 12/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0010 - val_loss: 9.6494e-04
# Epoch 13/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.3842e-04 - val_loss: 6.3606e-04
# Epoch 14/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.1526e-04 - val_loss: 0.0022
# Epoch 15/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0012 - val_loss: 5.7775e-04
# Epoch 16/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.9191e-04 - val_loss: 5.4724e-04
# Epoch 17/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.1675e-04 - val_loss: 6.9509e-04
# Epoch 18/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.2918e-04 - val_loss: 6.4308e-04
# Epoch 19/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.1164e-04 - val_loss: 7.0400e-04
# Epoch 20/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.5119e-04 - val_loss: 0.0015
# Epoch 21/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.2438e-04 - val_loss: 0.0031
# Epoch 22/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.5498e-04 - val_loss: 8.8171e-04
# Epoch 23/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.2799e-04 - val_loss: 0.0020
# Epoch 24/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.1037e-04 - val_loss: 4.2101e-04
# Epoch 25/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.9322e-04 - val_loss: 0.0013
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 1/25
# /var/folders/v7/c7_xhzbn47n7kzmqg4jkhntc0000gn/T/ipykernel_35081/4176298021.py:18: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill', inplace=True)  # Fill NaN values
# /Users/sindhukavyaalahari/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0538 - val_loss: 0.0019
# Epoch 2/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0037 - val_loss: 0.0016
# Epoch 3/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0030 - val_loss: 0.0015
# Epoch 4/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 5/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 6/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0023 - val_loss: 0.0016
# Epoch 7/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 8/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 9/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0022 - val_loss: 0.0014
# Epoch 10/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0022 - val_loss: 0.0013
# Epoch 11/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 12/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 13/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 14/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 15/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 16/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - val_loss: 9.5149e-04
# Epoch 17/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - val_loss: 8.9626e-04
# Epoch 18/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0017 - val_loss: 8.6695e-04
# Epoch 19/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - val_loss: 9.0745e-04
# Epoch 20/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - val_loss: 8.1692e-04
# Epoch 21/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0012 - val_loss: 7.9814e-04
# Epoch 22/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0013 - val_loss: 8.1379e-04
# Epoch 23/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0017 - val_loss: 8.5192e-04
# Epoch 24/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0013 - val_loss: 8.3205e-04
# Epoch 25/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - val_loss: 8.2265e-04
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 1/25
# /var/folders/v7/c7_xhzbn47n7kzmqg4jkhntc0000gn/T/ipykernel_35081/4176298021.py:18: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill', inplace=True)  # Fill NaN values
# /Users/sindhukavyaalahari/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0518 - val_loss: 0.0037
# Epoch 2/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0065 - val_loss: 0.0031
# Epoch 3/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0050 - val_loss: 0.0027
# Epoch 4/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0040 - val_loss: 0.0031
# Epoch 5/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0047 - val_loss: 0.0021
# Epoch 6/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0034 - val_loss: 0.0042
# Epoch 7/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0039 - val_loss: 0.0022
# Epoch 8/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0031 - val_loss: 0.0017
# Epoch 9/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0030 - val_loss: 0.0025
# Epoch 10/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0030 - val_loss: 0.0017
# Epoch 11/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0027 - val_loss: 0.0016
# Epoch 12/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0023 - val_loss: 0.0012
# Epoch 13/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 14/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0023 - val_loss: 0.0011
# Epoch 15/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0025 - val_loss: 0.0012
# Epoch 16/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 17/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 18/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 19/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 20/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 21/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0024 - val_loss: 0.0015
# Epoch 22/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 23/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 24/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 25/25
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0021 - val_loss: 0.0020
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Stock Prediction Evaluation Metrics:
#            Company          Model      RMSE       MAE  R-Squared
# 0       APPLE_data           LSTM  0.034548  0.025864   0.967004
# 1       APPLE_data            SVM  0.405687  0.329307  -3.549951
# 2       APPLE_data  Random Forest  0.207528  0.163566  -0.190639
# 3      GOOGLE_data           LSTM  0.057652  0.049098   0.767518
# 4      GOOGLE_data            SVM  0.398339  0.360923 -10.098477
# 5      GOOGLE_data  Random Forest  0.215092  0.187295  -2.235986
# 6   MICROSOFT_data           LSTM  0.066086  0.061480  -0.340615
# 7   MICROSOFT_data            SVM  0.301937  0.289858 -26.984308
# 8   MICROSOFT_data  Random Forest  0.093066  0.075713  -1.658688
# 9      AMAZON_data           LSTM  0.042387  0.034967   0.646977
# 10     AMAZON_data            SVM  0.207788  0.190150  -7.483590
# 11     AMAZON_data  Random Forest  0.085730  0.065250  -0.444112
# 12      TESLA_data           LSTM  0.049085  0.035169   0.886592
# 13      TESLA_data            SVM  0.059010  0.045817   0.836095
# 14      TESLA_data  Random Forest  0.035229  0.023257   0.941584

# %%
# Main Execution for Combined Dataset
sequence_length = 50

# Combine datasets
combined_df = pd.DataFrame()
for company in companies:
    file_path = company + ".csv"
    df = pd.read_csv(file_path, parse_dates=['Date'])
    df.set_index('Date', inplace=True)
    df = feature_engineering(df)
    combined_df = pd.concat([combined_df, df])

# Prepare combined data
X, y, scaler = prepare_data(combined_df, sequence_length)

# Sequential data split
X_train, X_test, y_train, y_test = split_data_sequential(X, y)

# Train LSTM
lstm_pred, lstm_actual = train_lstm(X_train, y_train, X_test, y_test, sequence_length)

# Evaluate LSTM model
lstm_rmse = np.sqrt(mean_squared_error(lstm_actual, lstm_pred))
lstm_mae = mean_absolute_error(lstm_actual, lstm_pred)
lstm_r2 = r2_score(lstm_actual, lstm_pred)

print(f"LSTM - RMSE: {lstm_rmse}, MAE: {lstm_mae}, R-Squared: {lstm_r2}")

# Train and evaluate SVM and Random Forest
y_test_flat, svm_pred, rf_pred = train_svm_rf(X, y)

# Evaluate SVM model
svm_rmse = np.sqrt(mean_squared_error(y_test_flat, svm_pred))
svm_mae = mean_absolute_error(y_test_flat, svm_pred)
svm_r2 = r2_score(y_test_flat, svm_pred)

print(f"SVM - RMSE: {svm_rmse}, MAE: {svm_mae}, R-Squared: {svm_r2}")

# Evaluate Random Forest model
rf_rmse = np.sqrt(mean_squared_error(y_test_flat, rf_pred))
rf_mae = mean_absolute_error(y_test_flat, rf_pred)
rf_r2 = r2_score(y_test_flat, rf_pred)

print(f"Random Forest - RMSE: {rf_rmse}, MAE: {rf_mae}, R-Squared: {rf_r2}")

# Plot predictions for LSTM
plt.figure(figsize=(10, 6))
plt.plot(lstm_actual, label='Actual')
plt.plot(lstm_pred, label='Predicted')
plt.title("Combined Dataset LSTM Prediction vs Actual")
plt.legend()
plt.show()
# Out:
# /var/folders/v7/c7_xhzbn47n7kzmqg4jkhntc0000gn/T/ipykernel_35081/4176298021.py:18: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill', inplace=True)  # Fill NaN values
# /var/folders/v7/c7_xhzbn47n7kzmqg4jkhntc0000gn/T/ipykernel_35081/4176298021.py:18: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill', inplace=True)  # Fill NaN values
# /var/folders/v7/c7_xhzbn47n7kzmqg4jkhntc0000gn/T/ipykernel_35081/4176298021.py:18: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill', inplace=True)  # Fill NaN values
# /var/folders/v7/c7_xhzbn47n7kzmqg4jkhntc0000gn/T/ipykernel_35081/4176298021.py:18: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill', inplace=True)  # Fill NaN values
# /var/folders/v7/c7_xhzbn47n7kzmqg4jkhntc0000gn/T/ipykernel_35081/4176298021.py:18: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill', inplace=True)  # Fill NaN values
# Epoch 1/25
# /Users/sindhukavyaalahari/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0058 - val_loss: 3.5340e-04
# Epoch 2/25
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 9.8003e-04 - val_loss: 2.9569e-04
# Epoch 3/25
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 6.7788e-04 - val_loss: 2.2707e-04
# Epoch 4/25
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 6.1324e-04 - val_loss: 5.0591e-04
# Epoch 5/25
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0012 - val_loss: 1.7879e-04
# Epoch 6/25
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 7.0068e-04 - val_loss: 1.7304e-04
# Epoch 7/25
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 3.7482e-04 - val_loss: 3.4155e-04
# Epoch 8/25
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 5.7887e-04 - val_loss: 1.4279e-04
# Epoch 9/25
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 4.1127e-04 - val_loss: 2.5985e-04
# Epoch 10/25
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 7.0307e-04 - val_loss: 1.3278e-04
# Epoch 11/25
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 3.4754e-04 - val_loss: 1.8614e-04
# Epoch 12/25
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 2.8273e-04 - val_loss: 1.3061e-04
# Epoch 13/25
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 3.7474e-04 - val_loss: 1.5399e-04
# Epoch 14/25
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 2.5906e-04 - val_loss: 1.2671e-04
# Epoch 15/25
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 2.8455e-04 - val_loss: 1.3538e-04
# Epoch 16/25
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 6.5180e-04 - val_loss: 2.0533e-04
# Epoch 17/25
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 3.5538e-04 - val_loss: 1.2159e-04
# Epoch 18/25
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 4.1285e-04 - val_loss: 1.4835e-04
# Epoch 19/25
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 3.6212e-04 - val_loss: 1.1540e-04
# Epoch 20/25
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 1.8289e-04 - val_loss: 1.1919e-04
# Epoch 21/25
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 2.6211e-04 - val_loss: 1.5534e-04
# Epoch 22/25
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 2.8517e-04 - val_loss: 4.1605e-04
# Epoch 23/25
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 5.4413e-04 - val_loss: 1.1005e-04
# Epoch 24/25
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 7.8419e-04 - val_loss: 1.4861e-04
# Epoch 25/25
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 3.3883e-04 - val_loss: 1.3610e-04
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# LSTM - RMSE: 0.03045124365341286, MAE: 0.022851476206401853, R-Squared: 0.9536128551742666
# SVM - RMSE: 0.07533612197426215, MAE: 0.05597124801612344, R-Squared: 0.7160812366691518
# Random Forest - RMSE: 0.03027202225940733, MAE: 0.021895957459707793, R-Squared: 0.9541572732622533
